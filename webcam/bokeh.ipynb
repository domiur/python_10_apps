# %%
from  bokeh.plotting import figure
from  bokeh.io import output_file,show
import pandas

# %%
x=[1,4,2,6]
y=[1,2,3,4]
output_file("line.html")
f=figure()
f.line(x,y)
f.triangle(x,y,size=10)
f.circle(x,y,size=15,fill_color=None)

show(f)

# %%
help(f.circle)
# Out:
# Help on method circle in module bokeh.plotting.glyph_api:
#
# circle(x='x', y='y', *, angle=0.0, angle_units='rad', fill_alpha=1.0, fill_color='gray', hatch_alpha=1.0, hatch_color='black', hatch_extra={}, hatch_pattern=None, hatch_scale=12.0, hatch_weight=1.0, hit_dilation=1.0, line_alpha=1.0, line_cap='butt', line_color='black', line_dash=[], line_dash_offset=0, line_join='bevel', line_width=1, name=None, radius=None, radius_dimension='x', radius_units='data', size=4, syncable=True, tags=[], **kwargs) method of bokeh.plotting.figure.Figure instance
#     Configure and add :class:`~bokeh.models.glyphs.Scatter` glyphs to this Figure.
#
#     Args:
#         x (:class:`~bokeh.core.properties.NumberSpec`\ , optional):
#             The x-axis coordinates for the center of the markers. (default: 'x')
#
#         y (:class:`~bokeh.core.properties.NumberSpec`\ , optional):
#             The y-axis coordinates for the center of the markers. (default: 'y')
#
#
#     Keyword args:
# ...

# %%
df=pandas.read_csv("bachelors.csv")
print(df.columns)
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %%
x=df['Year']
y=df['Engineering']

p=figure(plot_width=500,plot_height=400, tools='pan')

p.title.text="Cool Data"
p.title.text_color="Gray"
p.title.text_font="times"
p.title.text_font_style="bold"

p.xaxis.minor_tick_line_color=None
p.yaxis.minor_tick_line_color=None

p.xaxis.axis_label="Date"
p.yaxis.axis_label="Intensity"    

output_file("line.html")
p.line(x,y)
#f.triangle(x,y,size=10)
#f.circle(x,y,size=15,fill_color=None)

show(p)

# %%
help(p.scatter)
# Out:
# Help on method scatter in module bokeh.plotting.glyph_api:
#
# scatter(*args: 'Any', **kwargs: 'Any') -> 'GlyphRenderer' method of bokeh.plotting.figure.Figure instance
#     Creates a scatter plot of the given x and y items.
#
#     Args:
#         x (str or seq[float]) : values or field names of center x coordinates
#
#         y (str or seq[float]) : values or field names of center y coordinates
#
#         size (str or list[float]) : values or field names of sizes in |screen units|
#
#         marker (str, or list[str]): values or field names of marker types
#
#         color (color value, optional): shorthand to set both fill and line color
#
#         source (:class:`~bokeh.models.sources.ColumnDataSource`) : a user-supplied data source.
#             An attempt will be made to convert the object to :class:`~bokeh.models.sources.ColumnDataSource`
#             if needed. If none is supplied, one is created for the user automatically.
#
# ...

# %%
from openpyxl import load_workbook
wb = load_workbook('verlegenhuken.xlsx')
print(wb.sheetnames)
ws=wb['Ark1']
# Out:
# ['Ark1', 'Ark2', 'Ark3']

# %%
df=pandas.read_excel("verlegenhuken.xlsx",sheet_name=0)
df["Temperature"]=df["Temperature"]/10
df["Pressure"]=df["Pressure"]/10

# %%
df
# Out:
#        Year  Month  Day  Hour  Temperature  Pressure
# 0      2010     10    6     3         -3.0     998.4
# 1      2010     10    6     9         -2.8     999.2
# 2      2010     10    6    10         -2.4     998.7
# 3      2010     10    6    11         -1.9     998.7
# 4      2010     10    6    12         -1.9     998.5
# ...     ...    ...  ...   ...          ...       ...
# 33097  2014     12   30     9        -11.6     989.6
# 33098  2014     12   30    12        -10.3     986.6
# 33099  2014     12   30    15         -9.7     982.6
# 33100  2014     12   30    18         -9.3     982.9
# 33101  2014     12   30    21         -8.6     980.4
#
# [33102 rows x 6 columns]

# %%
df = pandas.DataFrame(ws.values)

# %%
df[4][1:df[4].shape[0]]
# Out:
# 1         -30
# 2         -28
# 3         -24
# 4         -19
# 5         -19
#          ...
# 33098    -116
# 33099    -103
# 33100     -97
# 33101     -93
# 33102     -86
# Name: 4, Length: 33102, dtype: object

# %%
x=df[4][1:df[4].shape[0]]/10
y=df[5][1:df[5].shape[0]]/10

p=figure(plot_width=500,plot_height=400, tools='pan')

p.title.text="Cool Data"
p.title.text_color="Gray"
p.title.text_font="times"
p.title.text_font_style="bold"

p.xaxis.minor_tick_line_color=None
p.yaxis.minor_tick_line_color=None

p.xaxis.axis_label=df[4][0]
p.yaxis.axis_label=df[5][0]

output_file("line.html")
p.scatter(x,y)
#f.triangle(x,y,size=10)
#f.circle(x,y,size=15,fill_color=None)

show(p)

# %% [markdown]
# # plot time series

# %%
df=pandas.read_csv("adbe.csv",parse_dates=["Date"])

p=figure(plot_width=500,plot_height=250, tools='pan',x_axis_type="datetime")
output_file("line.html")
p.line(df['Date'],df['Close'])
show(p)

# %%
df
# Out:
#           Date   Open   High    Low  Close    Volume
# 0   2012-08-02  30.46  30.83  30.25  30.58   2639980
# 1   2012-08-01  31.05  31.17  30.64  30.69   2738740
# 2   2012-07-31  30.99  31.27  30.84  30.88   2662853
# 3   2012-07-30  31.89  31.95  30.92  31.01   4261193
# 4   2012-07-27  31.26  32.00  31.17  31.90   3312890
# ..         ...    ...    ...    ...    ...       ...
# 898 2009-01-08  24.01  24.38  23.63  24.29   6207342
# 899 2009-01-07  23.57  24.81  23.51  24.23  12785603
# 900 2009-01-06  23.07  24.45  23.07  24.22   7032433
# 901 2009-01-05  22.52  23.31  22.50  23.13   7385533
# 902 2009-01-02  21.11  23.10  21.07  23.02   6673430
#
# [903 rows x 6 columns]

# %% [markdown]
# # plot data from detecting moving

# %%
df=pandas.read_csv("times.csv",parse_dates=["start","end"])

p=figure(plot_width=500,plot_height=250, tools='pan',x_axis_type="datetime")
output_file("line.html")
p.quad(df['Date'],df['Close'])
#show(p)

# %%
df
# Out:
#    Unnamed: 0                      start                        end
# 0           0 2021-12-13 16:07:06.011852 2021-12-13 16:07:10.483673
# 1           1 2021-12-13 16:07:11.483683 2021-12-13 16:07:12.283758
# 2           2 2021-12-13 16:07:13.219769 2021-12-13 16:07:14.283994
